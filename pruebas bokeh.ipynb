# %%
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show
from bokeh.layouts import column
from bokeh.models import Slider, ColumnDataSource, CheckboxGroup

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11775">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np
from numpy import cos, linspace

# %%
f = figure(height = 300)
plot = f.line('x', 'y', source=source)
show(f)
# Out:
#   <div class="bk-root" id="c6a4c7c6-e0a9-4065-956e-a415e8294716" data-root-id="11776"></div>

# %%
def bkapp(doc):
    
    p = figure(height = 300)
    chbox_ruido = CheckboxGroup(
        labels=['Ruido'], active=[])        
    slider = Slider(start=0, end=10, value=1, step=0.1, title="batata")
    
    doc.add_root(column(slider, chbox_ruido, p))
    
    x = linspace(-6, 6, 200)
    y = cos(x)
    ruido = np.zeros(y.shape)
    if chbox_ruido.active:
        ruido = 0.2*np.random.randn(y.size)
        
    source = ColumnDataSource({'x': x, 'y': y + ruido})
    p.line('x', 'y', source=source)
    
    def slider_change(attr, old, new):
        
        if chbox_ruido.active:
            ruido = 0.2*np.random.randn(y.size)
        else:
            ruido = np.zeros(y.shape)
            
        source.data = {'x': x, 'y': cos(new*x) + ruido}
    
    def chbox_ruido_change(attr, old, new):
        
        if new:
            ruido = 0.2*np.random.randn(y.size)
        else:
            ruido = np.zeros(y.shape)
            
        source.data = {'x': x, 'y': cos(slider.value*x) + ruido}
        
    slider.on_change('value', slider_change)
    chbox_ruido.on_change('active', chbox_ruido_change)

# %%
show(bkapp)
# Out:
# <script id="11960">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:41423/autoload.js?bokeh-autoload-element=11960&bokeh-absolute-url=http://localhost:41423&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
